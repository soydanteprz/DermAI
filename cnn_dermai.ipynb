# %% [markdown]
# # Classification of dermatoscopic images using Convolutional Neural Networks (CNNs)

# %% [markdown]
# Main library imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, models, layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.applications import MobileNetV2
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import time

# ========================================
# MAC M3 PRO GPU SETUP
# ========================================

def setup_gpu():
    """Configure TensorFlow for GPU acceleration if available"""

    gpus = tf.config.list_physical_devices('GPU')
    gpu_available = len(gpus) > 0

    if gpu_available:
        try:
            # Enable memory growth
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)

            # Mixed precision for better performance
            policy = tf.keras.mixed_precision.Policy('mixed_float16')
            tf.keras.mixed_precision.set_global_policy(policy)

            print("✅ GPU acceleration enabled")
        except Exception as e:
            print(f"GPU setup failed: {e}")
            gpu_available = False
    else:
        print("💻 Using CPU (no GPU detected)")

    return gpu_available


print("=" * 70)
print("6-class classification on balanced dataset")
print("Expected: 500 samples per class")
print("🖼Image size: 150×150 pixels")
print()

# Set up GPU before importing other modules
gpu_available = setup_gpu()

# Define paths
base_dir = os.path.join(os.getcwd(), 'data')
balanced_train_dir = os.path.join(base_dir, 'balanced_train')
test_dir = os.path.join(base_dir, 'test')
model_save_dir = os.path.join('models')
validation_dir = os.path.join(base_dir, 'validation')

# Create a models directory if it doesn't exist
os.makedirs(model_save_dir, exist_ok=True)

def verify_dataset():
    """Verify the balanced dataset and validation folder exist and check their structure"""

    print("VERIFYING DATASET...")
    print("-" * 40)

    if not os.path.exists(balanced_train_dir):
        raise FileNotFoundError("Balanced training dataset not found. Please run augmentation_script.py first.")

    if not os.path.exists(validation_dir):
        raise FileNotFoundError("Validation dataset not found. Please create a validation set.")

    if not os.path.exists(test_dir):
        raise FileNotFoundError("Test dataset not found. Please create a test set.")

    # Count classes and samples in each directory
    train_classes = [d for d in os.listdir(balanced_train_dir)
                     if os.path.isdir(os.path.join(balanced_train_dir, d))]
    val_classes = [d for d in os.listdir(validation_dir)
                   if os.path.isdir(os.path.join(validation_dir, d))]
    test_classes = [d for d in os.listdir(test_dir)
                    if os.path.isdir(os.path.join(test_dir, d))]

    print("✅ Dataset structure verified:")
    print(f"Training classes: {len(train_classes)} - {sorted(train_classes)}")
    print(f"Validation classes: {len(val_classes)} - {sorted(val_classes)}")
    print(f"Test classes: {len(test_classes)} - {sorted(test_classes)}")

    # Count samples in each directory
    total_train = 0
    total_val = 0
    total_test = 0

    for class_name in sorted(train_classes):
        train_count = len([f for f in os.listdir(os.path.join(balanced_train_dir, class_name))
                           if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
        val_count = len([f for f in os.listdir(os.path.join(validation_dir, class_name))
                         if f.lower().endswith(('.png', '.jpg', '.jpeg'))]) if class_name in val_classes else 0
        test_count = len([f for f in os.listdir(os.path.join(test_dir, class_name))
                          if f.lower().endswith(('.png', '.jpg', '.jpeg'))]) if class_name in test_classes else 0

        total_train += train_count
        total_val += val_count
        total_test += test_count

        print(f"     📊 {class_name}: Train={train_count}, Val={val_count}, Test={test_count}")

    print(f"📊 TOTAL SAMPLES:")
    print(f"Training: {total_train} samples")
    print(f"Validation: {total_val} samples")
    print(f"Test: {total_test} samples")
    print()
    return True

def create_data_generators():
    """Create optimized data generators using your separate train/validation/test folders"""

    print("📊 CREATING DATA GENERATORS (USING SEPARATE FOLDERS)...")
    print("-" * 40)

    # Optimized batch size for Mac M3 Pro GPU
    batch_size = 32 if gpu_available else 16  # Larger batch size for GPU, smaller for CPU

    # Training data generator WITH augmentation (only for training data)
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,        # Reduced from 180 (too aggressive)
        zoom_range=0.1,           # Reduced from 0.2
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.9, 1.1],
        fill_mode='nearest'
    )


    eval_datagen = ImageDataGenerator(rescale=1./255)


    train_generator = train_datagen.flow_from_directory(
        balanced_train_dir,
        target_size=(128, 128),  # Adjusted to 128x128 to match your dataset
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=42
    )

    validation_generator = eval_datagen.flow_from_directory(
        validation_dir,
        target_size=(128, 128),  # Adjusted to 128x128 to match your dataset
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=42
    )

    test_generator = eval_datagen.flow_from_directory(
        test_dir,
        target_size=(128, 128),  # Adjusted to 128x128 to match your dataset
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
    )

    print(f"✅ Training samples: {train_generator.samples} (from balanced_train/)")
    print(f"✅ Validation samples: {validation_generator.samples} (from validation/)")
    print(f"✅ Test samples: {test_generator.samples} (from test/)")
    print(f"✅ Batch size: {batch_size} (optimized for {'GPU' if gpu_available else 'CPU'})")
    print(f"✅ Number of classes: {len(train_generator.class_indices)}")
    print(f"✅ Class indices: {train_generator.class_indices}")
    print()

    # Verify class indices match across all generators
    if (train_generator.class_indices == validation_generator.class_indices == test_generator.class_indices):
        print("✅ Class indices consistent across all datasets")
    else:
        print(f"     Train: {train_generator.class_indices}")
        print(f"     Val: {validation_generator.class_indices}")
        print(f"     Test: {test_generator.class_indices}")

    return train_generator, validation_generator, test_generator

def create_model(model_type='mobilenet', num_classes=6, input_shape=(128, 128, 3)):
    """
    Create CNN model for skin cancer classification based on the paper's architectures.

    Parameters:
    -----------
    model_type : str
        'custom' for custom CNN or 'mobilenet' for MobileNetV2 (default)
    num_classes : int
        Number of output classes (default: 6)
    input_shape : tuple
        Input image shape (default: (128, 128, 3))

    Returns:
    --------
    model : keras.Model
        Compiled model ready for training
    """

    print(f"\n📊 CREATING {model_type.upper()} MODEL...")
    print("-" * 40)

    if model_type == 'custom':
        # Custom CNN Architecture from the paper
        # 3 blocks with each block containing 3 conv2d layers and a max pooling layer
        model = models.Sequential([
            # Input layer
            layers.Input(shape=input_shape),

            # Block 1
            layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
            layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
            layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
            layers.MaxPooling2D((2, 2)),
            layers.BatchNormalization(),

            # Block 2
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.MaxPooling2D((2, 2)),
            layers.BatchNormalization(),

            # Block 3
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.MaxPooling2D((2, 2)),
            layers.BatchNormalization(),

            # Flatten and Dense layers
            layers.GlobalAveragePooling2D(),
            layers.Dense(256, activation='relu'),
            layers.Dropout(0.5),
            layers.Dense(128, activation='relu'),
            layers.Dropout(0.5),
            layers.Dense(num_classes, activation='softmax')
        ])

        # Compile with SGD (best performer in the paper)
        optimizer = optimizers.SGD(learning_rate=0.001, momentum=0.9)

    elif model_type == 'mobilenet':
        # MobileNetV2 Architecture - Best performer in the paper
        # Load pre-trained MobileNetV2
        base_model = MobileNetV2(
            input_shape=input_shape,
            include_top=False,
            weights='imagenet'
        )

        # Freeze all layers except the last 23 (as per the paper)
        for layer in base_model.layers[:-23]:
            layer.trainable = False

        # Print info about frozen layers
        trainable_count = sum([1 for layer in base_model.layers if layer.trainable])
        non_trainable_count = len(base_model.layers) - trainable_count
        print(f"✅ Base model layers: {len(base_model.layers)}")
        print(f"✅ Trainable layers: {trainable_count}")
        print(f"✅ Frozen layers: {non_trainable_count}")

        # Build the complete model
        inputs = layers.Input(shape=input_shape)

        # Apply the base model
        x = base_model(inputs, training=True)

        # Add custom classification head
        x = layers.GlobalAveragePooling2D()(x)
        x = layers.Dense(256, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.5)(x)
        x = layers.Dense(128, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.5)(x)

        # Output layer
        outputs = layers.Dense(num_classes, activation='softmax', dtype='float32')(x)  # float32 for mixed precision

        model = models.Model(inputs, outputs)

        # Use SGD optimizer (achieved 96.19% accuracy in the paper)
        optimizer = optimizers.SGD(learning_rate=0.001, momentum=0.9)

    else:
        raise ValueError(f"Unknown model type: {model_type}. Choose 'custom' or 'mobilenet'")

    # Compile the model
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Print model summary
    print("\n📊 MODEL ARCHITECTURE:")
    print("-" * 40)
    model.summary()

    # Calculate and display model statistics
    total_params = model.count_params()
    trainable_params = sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print("\n📊 MODEL STATISTICS:")
    print("-" * 40)
    print(f"✅ Total parameters: {total_params:,}")
    print(f"✅ Trainable parameters: {trainable_params:,}")
    print(f"✅ Non-trainable parameters: {non_trainable_params:,}")
    print(f"✅ Model size: ~{total_params * 4 / 1024 / 1024:.2f} MB (float32)")

    # GPU memory estimation
    if gpu_available:
        # Rough estimation of GPU memory needed
        batch_size = 32
        input_size = batch_size * 128 * 128 * 3 * 4  # float32
        param_size = total_params * 4  # float32
        activation_size = total_params * 4 * 0.5  # rough estimate
        total_memory = (input_size + param_size + activation_size) / 1024 / 1024
        print(f"✅ Estimated GPU memory usage: ~{total_memory:.0f} MB")

    print()

    return model

def create_callbacks():
    """Create training callbacks optimized for Mac M3 Pro GPU training"""

    print("⚙SETTING UP TRAINING CALLBACKS (MAC M3 PRO OPTIMIZED)...")
    print("-" * 40)

    # Reduce the learning rate with GPU-optimized settings
    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=8,
        min_lr=1e-6,
        verbose=1,
        mode='max',  # Explicitly set mode for accuracy
    )

    # Save the best model during training - Fixed version
    model_checkpoint = ModelCheckpoint(
        filepath=os.path.join(model_save_dir, 'best_model_m3_pro.keras'),
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=False,
        mode='max',  # Explicitly set mode for accuracy
        verbose=1,
        initial_value_threshold=0.0
    )


    callbacks = [model_checkpoint, reduce_lr]

    # Add TensorBoard callback for GPU monitoring
    if gpu_available:
        tensorboard_dir = os.path.join(model_save_dir, 'tensorboard_logs')
        os.makedirs(tensorboard_dir, exist_ok=True)

        try:
            tensorboard_callback = tf.keras.callbacks.TensorBoard(
                log_dir=tensorboard_dir,
                histogram_freq=1,
                write_graph=True,
                write_images=False,
                update_freq='epoch'
            )
            callbacks.append(tensorboard_callback)

            print("TensorBoard logging enabled for GPU monitoring")
            print(f"Logs saved to: {tensorboard_dir}")
            print("Run: tensorboard --logdir tensorboard_logs")
        except Exception as e:
            print(f"TensorBoard setup failed: {e}")
            print("Training will continue without TensorBoard")

    print("Callbacks configured:")
    print(f"Learning Rate Reduction (patience={5 if gpu_available else 3})")
    print("Model Checkpoint (best validation accuracy)")
    print()

    return callbacks

def train_model(model, train_generator, validation_generator, callbacks):
    """Train the model with Mac M3 Pro GPU acceleration"""

    print("STARTING MODEL TRAINING")
    print("=" * 70)

    # Calculate steps per epoch
    steps_per_epoch = train_generator.samples // train_generator.batch_size
    validation_steps = validation_generator.samples // validation_generator.batch_size

    # Optimized epochs for GPU training
    max_epochs = 20

    print(f"Training configuration:")
    print(f"Device: {'Mac M3 Pro GPU' if gpu_available else 'CPU'}")
    print(f"Steps per epoch: {steps_per_epoch}")
    print(f"Validation steps: {validation_steps}")
    print(f"     Batch size: {train_generator.batch_size}")
    print(f"     Mixed precision: {'Enabled' if tf.keras.mixed_precision.global_policy().name == 'mixed_float16' else 'Disabled'}")
    print()

    start_time = time.time()


    # Train the model
    history = model.fit(
        train_generator,
        epochs=max_epochs,
        steps_per_epoch=steps_per_epoch,
        validation_data=validation_generator,
        validation_steps=validation_steps,
        callbacks=callbacks,
        verbose=1,
    )

    # Calculate training time
    training_time = time.time() - start_time
    hours = int(training_time // 3600)
    minutes = int((training_time % 3600) // 60)
    seconds = int(training_time % 60)

    print(f"\nTRAINING COMPLETED!")
    print("=" * 70)
    print(f"⏱Training time: {hours:02d}:{minutes:02d}:{seconds:02d}")
    print(f"Total epochs completed: {len(history.history['accuracy'])}")
    print()

    return history

def visualize_training_results(history):
    """Create comprehensive training visualizations with soft styling"""

    print("CREATING TRAINING VISUALIZATIONS")
    print("-" * 40)

    # Set up softer plotting style
    plt.style.use('seaborn-v0_8-darkgrid')  # Softer grid style
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.patch.set_facecolor('white')

    epochs_range = range(1, len(history.history['accuracy']) + 1)

    # Soft color palette
    train_color = '#2E86AB'    # Soft blue
    val_color = '#A23B72'      # Soft red/pink
    lr_color = '#F18F01'       # Soft orange

    # Training and Validation Accuracy (0 to 1 range)
    axes[0, 0].plot(epochs_range, history.history['accuracy'],
                    color=train_color, linewidth=2.5, alpha=0.8,
                    label='Training Accuracy', marker='o', markersize=3,
                    markerfacecolor=train_color, markeredgecolor='white', markeredgewidth=0.5)
    axes[0, 0].plot(epochs_range, history.history['val_accuracy'],
                    color=val_color, linewidth=2.5, alpha=0.8,
                    label='Validation Accuracy', marker='s', markersize=3,
                    markerfacecolor=val_color, markeredgecolor='white', markeredgewidth=0.5)

    axes[0, 0].set_title('Model Accuracy', fontsize=15, fontweight='bold', pad=15)
    axes[0, 0].set_xlabel('Epochs', fontsize=12)
    axes[0, 0].set_ylabel('Accuracy', fontsize=12)
    axes[0, 0].set_ylim(0, 1)  # Fixed range from 0 to 1
    axes[0, 0].legend(frameon=True, fancybox=True, shadow=True, loc='lower right')
    axes[0, 0].grid(True, alpha=0.3, linestyle='--')
    axes[0, 0].set_facecolor('#fafafa')

    # Training and Validation Loss
    axes[0, 1].plot(epochs_range, history.history['loss'],
                    color=train_color, linewidth=2.5, alpha=0.8,
                    label='Training Loss', marker='o', markersize=3,
                    markerfacecolor=train_color, markeredgecolor='white', markeredgewidth=0.5)
    axes[0, 1].plot(epochs_range, history.history['val_loss'],
                    color=val_color, linewidth=2.5, alpha=0.8,
                    label='Validation Loss', marker='s', markersize=3,
                    markerfacecolor=val_color, markeredgecolor='white', markeredgewidth=0.5)

    axes[0, 1].set_title('Model Loss', fontsize=15, fontweight='bold', pad=15)
    axes[0, 1].set_xlabel('Epochs', fontsize=12)
    axes[0, 1].set_ylabel('Loss', fontsize=12)
    axes[0, 1].legend(frameon=True, fancybox=True, shadow=True, loc='upper right')
    axes[0, 1].grid(True, alpha=0.3, linestyle='--')
    axes[0, 1].set_facecolor('#fafafa')

    # Learning Rate (if available)
    if 'lr' in history.history:
        axes[1, 0].plot(epochs_range, history.history['lr'],
                        color=lr_color, linewidth=2.5, alpha=0.8,
                        label='Learning Rate', marker='d', markersize=3,
                        markerfacecolor=lr_color, markeredgecolor='white', markeredgewidth=0.5)
        axes[1, 0].set_title('Learning Rate Schedule', fontsize=15, fontweight='bold', pad=15)
        axes[1, 0].set_xlabel('Epochs', fontsize=12)
        axes[1, 0].set_ylabel('Learning Rate', fontsize=12)
        axes[1, 0].set_yscale('log')
        axes[1, 0].legend(frameon=True, fancybox=True, shadow=True)
        axes[1, 0].grid(True, alpha=0.3, linestyle='--')
        axes[1, 0].set_facecolor('#fafafa')
    else:
        axes[1, 0].text(0.5, 0.5, 'Learning Rate\nHistory Not Available',
                        horizontalalignment='center', verticalalignment='center',
                        transform=axes[1, 0].transAxes, fontsize=14,
                        bbox=dict(boxstyle='round,pad=0.5', facecolor='lightblue', alpha=0.7))
        axes[1, 0].set_title('Learning Rate Schedule', fontsize=15, fontweight='bold', pad=15)
        axes[1, 0].set_facecolor('#fafafa')

    # Training Summary Statistics with improved styling
    axes[1, 1].axis('off')

    # Calculate final metrics
    final_train_acc = history.history['accuracy'][-1]
    final_val_acc = history.history['val_accuracy'][-1]
    final_train_loss = history.history['loss'][-1]
    final_val_loss = history.history['val_loss'][-1]
    best_val_acc = max(history.history['val_accuracy'])

    # Status with color coding
    gap = abs(final_train_acc - final_val_acc)
    if gap < 0.05:
        status = "Excellent"
        status_color = "#2E8B57"  # Sea green
    elif gap < 0.1:
        status = "Good"
        status_color = "#FF8C00"  # Dark orange
    else:
        status = "Overfitting"
        status_color = "#DC143C"  # Crimson

    summary_text = f"""TRAINING SUMMARY
    ══════════════════════════════

    >> Final Training Accuracy:     {final_train_acc:.4f} ({final_train_acc*100:.2f}%)
    >> Final Validation Accuracy:   {final_val_acc:.4f} ({final_val_acc*100:.2f}%)
    ** Best Validation Accuracy:    {best_val_acc:.4f} ({best_val_acc*100:.2f}%)

    >> Final Training Loss:         {final_train_loss:.4f}
    >> Final Validation Loss:       {final_val_loss:.4f}

    >> Total Epochs:                {len(epochs_range)}

    >> Overfitting Analysis:
    ├── Accuracy Gap:               {gap:.4f} ({gap*100:.2f}%)
    └── Status:                     {status}
    """

    axes[1, 1].text(0.05, 0.95, summary_text, transform=axes[1, 1].transAxes,
                    fontsize=11, verticalalignment='top', fontfamily='sans-serif',
                    bbox=dict(boxstyle='round,pad=0.8', facecolor='#f8f9fa',
                              edgecolor=status_color, linewidth=2, alpha=0.9))

    # Add a subtle background gradient effect
    for ax in axes.flat:
        if ax != axes[1, 1]:  # Don't apply to summary plot
            ax.set_axisbelow(True)

    plt.tight_layout(pad=3.0)
    plt.suptitle('Training Results Overview', fontsize=18, fontweight='bold',
                 y=0.98, color='#2c3e50')

    # Save the plot with higher quality
    plot_path = os.path.join(model_save_dir, 'training_history.png')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight', facecolor='white',
                edgecolor='none', format='png')
    print(f"✅ Training plots saved to: {plot_path}")
    plt.show()

def evaluate_model(model, test_generator):
    """Comprehensive model evaluation on a test set"""

    print("EVALUATING MODEL ON TEST SET...")
    print("=" * 70)

    # Evaluate model
    test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)

    print(f"\nTEST RESULTS:")
    print(f"     Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
    print(f"     Test Loss: {test_loss:.4f}")

    # Generate predictions for detailed analysis
    print("\nGENERATING DETAILED PREDICTIONS...")

    # Get predictions
    test_generator.reset()
    predictions = model.predict(test_generator, verbose=1)
    predicted_classes = np.argmax(predictions, axis=1)

    # Get true labels
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Classification report
    print("\n📋 CLASSIFICATION REPORT:")
    print("=" * 70)
    report = classification_report(true_classes, predicted_classes,
                                   target_names=class_labels, digits=4)
    print(report)

    # Save a classification report
    report_path = os.path.join(model_save_dir, 'classification_report.txt')
    with open(report_path, 'w') as f:
        f.write("SKIN LESION CLASSIFICATION REPORT\n")
        f.write("=" * 50 + "\n\n")
        f.write(f"Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)\n")
        f.write(f"Test Loss: {test_loss:.4f}\n\n")
        f.write("DETAILED CLASSIFICATION REPORT:\n")
        f.write(report)

    print(f"✅ Classification report saved to: {report_path}")

    # Confusion Matrix
    create_confusion_matrix(true_classes, predicted_classes, class_labels)

    return test_accuracy, test_loss

def create_confusion_matrix(true_classes, predicted_classes, class_labels):
    """Create and display confusion matrix"""

    print("\n📊 CREATING CONFUSION MATRIX...")

    # Calculate confusion matrix
    cm = confusion_matrix(true_classes, predicted_classes)

    # Create a figure
    plt.figure(figsize=(10, 8))

    # Create heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_labels, yticklabels=class_labels,
                cbar_kws={'label': 'Number of Samples'})

    plt.title('Confusion Matrix - Skin Lesion Classification',
              fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Labels', fontsize=12)
    plt.ylabel('True Labels', fontsize=12)

    # Add accuracy per class
    class_accuracies = cm.diagonal() / cm.sum(axis=1)
    for i, acc in enumerate(class_accuracies):
        plt.text(len(class_labels) + 0.5, i + 0.5, f'{acc:.3f}',
                 ha='center', va='center', fontweight='bold', color='red')

    plt.tight_layout()

    # Save confusion matrix
    cm_path = os.path.join(model_save_dir, 'confusion_matrix.png')
    plt.savefig(cm_path, dpi=300, bbox_inches='tight')
    print(f"✅ Confusion matrix saved to: {cm_path}")
    plt.show()

    # Print per-class accuracy
    print("\n📊 PER-CLASS ACCURACY:")
    print("-" * 40)
    for i, (label, acc) in enumerate(zip(class_labels, class_accuracies)):
        print(f"     {label}: {acc:.4f} ({acc*100:.2f}%)")

def save_model_info(model, history, test_accuracy):
    """Save comprehensive model information"""

    print("\nSAVING MODEL INFORMATION...")

    # Save model architecture
    model_json = model.to_json()
    json_path = os.path.join(model_save_dir, 'model_architecture.json')
    with open(json_path, 'w') as json_file:
        json_file.write(model_json)

    # Save model weights
    weights_path = os.path.join(model_save_dir, 'model.weights.h5')
    model.save_weights(weights_path)

    # Save a complete model
    full_model_path = os.path.join(model_save_dir, 'complete_model.keras')
    model.save(full_model_path)

    # Save training history
    history_df = pd.DataFrame(history.history)
    history_path = os.path.join(model_save_dir, 'training_history.csv')
    history_df.to_csv(history_path, index=False)

    # Create a model summary file
    summary_path = os.path.join(model_save_dir, 'model_summary.txt')
    with open(summary_path, 'w') as f:
        f.write("SKIN LESION CLASSIFICATION MODEL SUMMARY\n")
        f.write("=" * 50 + "\n\n")
        f.write(f"Model Type: Convolutional Neural Network (CNN)\n")
        f.write(f"Input Shape: (150, 150, 3)\n")
        f.write(f"Number of Classes: 6\n")
        f.write(f"Total Parameters: {model.count_params():,}\n")
        f.write(f"Training Epochs: {len(history.history['accuracy'])}\n")
        f.write(f"Best Validation Accuracy: {max(history.history['val_accuracy']):.4f}\n")
        f.write(f"Final Test Accuracy: {test_accuracy:.4f}\n\n")
        f.write("Classes:\n")
        f.write("- ACK: Actinic Keratosis\n")
        f.write("- BCC: Basal Cell Carcinoma\n")
        f.write("- MEL: Melanoma\n")
        f.write("- NEV: Nevus\n")
        f.write("- SEK: Seborrheic Keratosis\n")
        f.write("- SCC: Squamous Cell Carcinoma\n\n")
        f.write("Files Saved:\n")
        f.write(f"- Complete Model: {full_model_path}\n")
        f.write(f"- Model Weights: {weights_path}\n")
        f.write(f"- Model Architecture: {json_path}\n")
        f.write(f"- Training History: {history_path}\n")

    print("✅ Model information saved:")
    print(f"Model summary: {summary_path}")
    print(f"Complete model: {full_model_path}")
    print(f"Model weights: {weights_path}")
    print(f"Model architecture: {json_path}")
    print(f"Training history: {history_path}")

def main():
    """Main execution function"""

    # Verify dataset exists
    if not verify_dataset():
        print("TRAINING ABORTED: Dataset verification failed")
        return

    # Create data generators
    train_gen, val_gen, test_gen = create_data_generators()

    # Create model
    model = create_model()

    # Setup callbacks
    callbacks = create_callbacks()

    # Train model
    history = train_model(model, train_gen, val_gen, callbacks)

    # Load the best model for evaluation
    best_model_path = os.path.join(model_save_dir, 'best_model_m3_pro.keras')
    if os.path.exists(best_model_path):
        print("Loading best model for evaluation...")
        model = tf.keras.models.load_model(best_model_path)


    # Visualize training results
    visualize_training_results(history)

    # Evaluate model
    test_accuracy, test_loss = evaluate_model(model, test_gen)

    # Save model and information
    save_model_info(model, history, test_accuracy)

    # Final summary
    print("\nMODEL TRAINING COMPLETED SUCCESSFULLY")
    print("=" * 70)

    print(f"🎯 Final Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
    print(f"📁 All results saved in: {model_save_dir}")


if __name__ == "__main__":
    # Set random seeds for reproducibility
    np.random.seed(42)
    tf.random.set_seed(42)

    # Run the main training pipeline
    main()
# Out:
# ======================================================================
# 6-class classification on balanced dataset
# Expected: 500 samples per class
# 🖼Image size: 150×150 pixels
#
# ✅ GPU acceleration enabled
# VERIFYING DATASET...
# ----------------------------------------
# ✅ Dataset structure verified:
# Training classes: 6 - ['ACK', 'BCC', 'MEL', 'NEV', 'SCC', 'SEK']
# Validation classes: 6 - ['ACK', 'BCC', 'MEL', 'NEV', 'SCC', 'SEK']
# Test classes: 6 - ['ACK', 'BCC', 'MEL', 'NEV', 'SCC', 'SEK']
#      📊 ACK: Train=500, Val=72, Test=146
#      📊 BCC: Train=500, Val=84, Test=168
#      📊 MEL: Train=500, Val=6, Test=13
#      📊 NEV: Train=500, Val=25, Test=52
#      📊 SCC: Train=500, Val=18, Test=39
#      📊 SEK: Train=500, Val=23, Test=47
# 📊 TOTAL SAMPLES:
# Training: 3000 samples
# Validation: 228 samples
# Test: 465 samples
#
# 📊 CREATING DATA GENERATORS (USING SEPARATE FOLDERS)...
# ----------------------------------------
# Found 3000 images belonging to 6 classes.
# Found 228 images belonging to 6 classes.
# Found 465 images belonging to 6 classes.
# ✅ Training samples: 3000 (from balanced_train/)
# ✅ Validation samples: 228 (from validation/)
# ✅ Test samples: 465 (from test/)
# ✅ Batch size: 32 (optimized for GPU)
# ✅ Number of classes: 6
# ✅ Class indices: {'ACK': 0, 'BCC': 1, 'MEL': 2, 'NEV': 3, 'SCC': 4, 'SEK': 5}
#
# ✅ Class indices consistent across all datasets
#
# 📊 CREATING MOBILENET MODEL...
# ----------------------------------------
# 2025-05-27 13:06:41.596156: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-05-27 13:06:41.596185: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-05-27 13:06:41.596192: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-05-27 13:06:41.596206: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-27 13:06:41.596216: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ✅ Base model layers: 154
# ✅ Trainable layers: 23
# ✅ Frozen layers: 131
#
# 📊 MODEL ARCHITECTURE:
# ----------------------------------------
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_128            │ (None, 4, 4, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,621,126 (10.00 MB)
#  Trainable params: 1,722,374 (6.57 MB)
#  Non-trainable params: 898,752 (3.43 MB)
# 📊 MODEL STATISTICS:
# ----------------------------------------
# ✅ Total parameters: 2,621,126
# ✅ Trainable parameters: 1,722,374
# ✅ Non-trainable parameters: 898,752
# ✅ Model size: ~10.00 MB (float32)
# ✅ Estimated GPU memory usage: ~21 MB
#
# ⚙SETTING UP TRAINING CALLBACKS (MAC M3 PRO OPTIMIZED)...
# ----------------------------------------
# TensorBoard logging enabled for GPU monitoring
# Logs saved to: models/tensorboard_logs
# Run: tensorboard --logdir tensorboard_logs
# Callbacks configured:
# Learning Rate Reduction (patience=5)
# Model Checkpoint (best validation accuracy)
#
# STARTING MODEL TRAINING
# ======================================================================
# Training configuration:
# Device: Mac M3 Pro GPU
# Steps per epoch: 93
# Validation steps: 7
#      Batch size: 32
#      Mixed precision: Enabled
# /Users/daperez/miniconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 2025-05-27 13:06:43.889790: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.2129 - loss: 2.6979
# Epoch 1: val_accuracy improved from 0.00000 to 0.38393, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 41s 404ms/step - accuracy: 0.2136 - loss: 2.6939 - val_accuracy: 0.3839 - val_loss: 1.4336 - learning_rate: 0.0010
# Epoch 2/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.1250 - loss: 2.4238
# /Users/daperez/miniconda3/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.38393
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.1250 - loss: 2.4238 - val_accuracy: 0.3795 - val_loss: 1.4326 - learning_rate: 0.0010
# Epoch 3/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.3654 - loss: 1.8474
# Epoch 3: val_accuracy improved from 0.38393 to 0.40179, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 36s 392ms/step - accuracy: 0.3656 - loss: 1.8463 - val_accuracy: 0.4018 - val_loss: 1.4137 - learning_rate: 0.0010
# Epoch 4/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.3125 - loss: 1.6634
# Epoch 4: val_accuracy did not improve from 0.40179
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.3125 - loss: 1.6634 - val_accuracy: 0.4018 - val_loss: 1.4142 - learning_rate: 0.0010
# Epoch 5/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.4320 - loss: 1.5347
# Epoch 5: val_accuracy improved from 0.40179 to 0.43304, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 398ms/step - accuracy: 0.4320 - loss: 1.5346 - val_accuracy: 0.4330 - val_loss: 1.3380 - learning_rate: 0.0010
# Epoch 6/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.5312 - loss: 1.3939
# Epoch 6: val_accuracy improved from 0.43304 to 0.43750, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.5312 - loss: 1.3939 - val_accuracy: 0.4375 - val_loss: 1.3360 - learning_rate: 0.0010
# Epoch 7/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.4837 - loss: 1.4191
# Epoch 7: val_accuracy improved from 0.43750 to 0.48661, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 396ms/step - accuracy: 0.4837 - loss: 1.4189 - val_accuracy: 0.4866 - val_loss: 1.3088 - learning_rate: 0.0010
# Epoch 8/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.5000 - loss: 1.3700
# Epoch 8: val_accuracy did not improve from 0.48661
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.5000 - loss: 1.3700 - val_accuracy: 0.4821 - val_loss: 1.3083 - learning_rate: 0.0010
# Epoch 9/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.4753 - loss: 1.3660
# Epoch 9: val_accuracy did not improve from 0.48661
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 391ms/step - accuracy: 0.4754 - loss: 1.3657 - val_accuracy: 0.4554 - val_loss: 1.3014 - learning_rate: 0.0010
# Epoch 10/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.4375 - loss: 1.3327
# Epoch 10: val_accuracy did not improve from 0.48661
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.4375 - loss: 1.3327 - val_accuracy: 0.4598 - val_loss: 1.3023 - learning_rate: 0.0010
# Epoch 11/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5142 - loss: 1.2594
# Epoch 11: val_accuracy did not improve from 0.48661
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 393ms/step - accuracy: 0.5143 - loss: 1.2593 - val_accuracy: 0.4598 - val_loss: 1.2917 - learning_rate: 0.0010
# Epoch 12/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.4688 - loss: 1.4801
# Epoch 12: val_accuracy did not improve from 0.48661
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.4688 - loss: 1.4801 - val_accuracy: 0.4643 - val_loss: 1.2926 - learning_rate: 0.0010
# Epoch 13/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5215 - loss: 1.2397
# Epoch 13: val_accuracy improved from 0.48661 to 0.49554, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 400ms/step - accuracy: 0.5216 - loss: 1.2393 - val_accuracy: 0.4955 - val_loss: 1.3006 - learning_rate: 0.0010
# Epoch 14/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.6562 - loss: 0.8163
# Epoch 14: val_accuracy did not improve from 0.49554
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.6562 - loss: 0.8163 - val_accuracy: 0.4955 - val_loss: 1.3006 - learning_rate: 0.0010
# Epoch 15/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5801 - loss: 1.1516
# Epoch 15: val_accuracy improved from 0.49554 to 0.50446, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 401ms/step - accuracy: 0.5801 - loss: 1.1514 - val_accuracy: 0.5045 - val_loss: 1.2744 - learning_rate: 0.0010
# Epoch 16/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.5312 - loss: 1.2505
# Epoch 16: val_accuracy improved from 0.50446 to 0.51339, saving model to models/best_model_m3_pro.keras
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.5312 - loss: 1.2505 - val_accuracy: 0.5134 - val_loss: 1.2726 - learning_rate: 0.0010
# Epoch 17/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5907 - loss: 1.0837
# Epoch 17: val_accuracy did not improve from 0.51339
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.5906 - loss: 1.0840 - val_accuracy: 0.4643 - val_loss: 1.3506 - learning_rate: 0.0010
# Epoch 18/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.5625 - loss: 1.2643
# Epoch 18: val_accuracy did not improve from 0.51339
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.5625 - loss: 1.2643 - val_accuracy: 0.4554 - val_loss: 1.3484 - learning_rate: 0.0010
# Epoch 19/20
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5828 - loss: 1.0921
# Epoch 19: val_accuracy did not improve from 0.51339
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 37s 397ms/step - accuracy: 0.5829 - loss: 1.0920 - val_accuracy: 0.5000 - val_loss: 1.3089 - learning_rate: 0.0010
# Epoch 20/20
#  1/93 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.4062 - loss: 1.3524
# Epoch 20: val_accuracy did not improve from 0.51339
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.4062 - loss: 1.3524 - val_accuracy: 0.4955 - val_loss: 1.3051 - learning_rate: 0.0010
#
# TRAINING COMPLETED!
# ======================================================================
# ⏱Training time: 00:07:02
# Total epochs completed: 20
#
# Loading best model for evaluation...
# CREATING TRAINING VISUALIZATIONS
# ----------------------------------------
# ✅ Training plots saved to: models/training_history.png
# EVALUATING MODEL ON TEST SET...
# ======================================================================
# /Users/daperez/miniconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 529ms/step - accuracy: 0.6090 - loss: 0.9806
#
# TEST RESULTS:
#      Test Accuracy: 0.5032 (50.32%)
#      Test Loss: 1.2738
#
# GENERATING DETAILED PREDICTIONS...
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 593ms/step
#
# 📋 CLASSIFICATION REPORT:
# ======================================================================
#               precision    recall  f1-score   support
#
#          ACK     0.5417    0.6233    0.5796       146
#          BCC     0.5263    0.6548    0.5836       168
#          MEL     0.1250    0.0769    0.0952        13
#          NEV     0.5862    0.3269    0.4198        52
#          SCC     0.0000    0.0000    0.0000        39
#          SEK     0.3125    0.3191    0.3158        47
#
#     accuracy                         0.5032       465
#    macro avg     0.3486    0.3335    0.3323       465
# weighted avg     0.4609    0.5032    0.4743       465
#
# ✅ Classification report saved to: models/classification_report.txt
#
# 📊 CREATING CONFUSION MATRIX...
# ✅ Confusion matrix saved to: models/confusion_matrix.png
# 📊 PER-CLASS ACCURACY:
# ----------------------------------------
#      ACK: 0.6233 (62.33%)
#      BCC: 0.6548 (65.48%)
#      MEL: 0.0769 (7.69%)
#      NEV: 0.3269 (32.69%)
#      SCC: 0.0000 (0.00%)
#      SEK: 0.3191 (31.91%)
#
# SAVING MODEL INFORMATION...
# ✅ Model information saved:
# Model summary: models/model_summary.txt
# Complete model: models/complete_model.keras
# Model weights: models/model.weights.h5
# Model architecture: models/model_architecture.json
# Training history: models/training_history.csv
#
# MODEL TRAINING COMPLETED SUCCESSFULLY
# ======================================================================
# 🎯 Final Test Accuracy: 0.5032 (50.32%)
# 📁 All results saved in: models
